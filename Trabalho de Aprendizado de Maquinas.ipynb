# %%
import sklearn
import pandas as pd
import statistics
import matplotlib.pyplot as plt
df = pd.read_excel('dataset.xlsx')

# %%
print("O dataset possui {} linhas e {} colunas".format(df.shape[0], df.shape[1]))
df.isnull().sum()

# Definindo a porcentagem máxima de valores nulos permitida
media_porcentagem_nulos_df = df.isna().mean().mean()

# Loop pelas colunas do DataFrame
for coluna in df.columns:
    # Calculando a porcentagem de valores nulos na coluna
    porcentagem_nulos = df[coluna].isnull().sum() / len(df)
    print(f"Coluna {coluna} não eliminada porcentagem de nulos: {porcentagem_nulos:.2%} de valores nulos.")
    # Verificando se a porcentagem de valores nulos na coluna é maior ou igual ao limite máximo permitido
    if porcentagem_nulos >= media_porcentagem_nulos_df:
        # Imprimindo mensagem informando que a coluna será eliminada
        print(f"Coluna {coluna} será eliminada por conter {porcentagem_nulos:.2%} de valores nulos.")
        # Removendo a coluna do DataFrame
        df.drop(columns=[coluna], inplace=True)
# Out:
# O dataset possui 5644 linhas e 111 colunas
# There are 88.1% of missing values in the dataset.
# Coluna Patient ID não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna Patient age quantile não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna SARS-Cov-2 exam result não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna Patient addmited to regular ward (1=yes, 0=no) não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna Patient addmited to semi-intensive unit (1=yes, 0=no) não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna Patient addmited to intensive care unit (1=yes, 0=no) não eliminada porcentagem de nulos: 0.00% de valores nulos.
# Coluna Hematocrit não eliminada porcentagem de nulos: 89.32% de valores nulos.
# Coluna Hematocrit será eliminada por conter 89.32% de valores nulos.
# Coluna Hemoglobin não eliminada porcentagem de nulos: 89.32% de valores nulos.
# Coluna Hemoglobin será eliminada por conter 89.32% de valores nulos.
# Coluna Platelets não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Platelets será eliminada por conter 89.33% de valores nulos.
# Coluna Mean platelet volume  não eliminada porcentagem de nulos: 89.39% de valores nulos.
# Coluna Mean platelet volume  será eliminada por conter 89.39% de valores nulos.
# Coluna Red blood Cells não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Red blood Cells será eliminada por conter 89.33% de valores nulos.
# Coluna Lymphocytes não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Lymphocytes será eliminada por conter 89.33% de valores nulos.
# Coluna Mean corpuscular hemoglobin concentration (MCHC) não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Mean corpuscular hemoglobin concentration (MCHC) será eliminada por conter 89.33% de valores nulos.
# Coluna Leukocytes não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Leukocytes será eliminada por conter 89.33% de valores nulos.
# Coluna Basophils não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Basophils será eliminada por conter 89.33% de valores nulos.
# Coluna Mean corpuscular hemoglobin (MCH) não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Mean corpuscular hemoglobin (MCH) será eliminada por conter 89.33% de valores nulos.
# Coluna Eosinophils não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Eosinophils será eliminada por conter 89.33% de valores nulos.
# Coluna Mean corpuscular volume (MCV) não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Mean corpuscular volume (MCV) será eliminada por conter 89.33% de valores nulos.
# Coluna Monocytes não eliminada porcentagem de nulos: 89.35% de valores nulos.
# Coluna Monocytes será eliminada por conter 89.35% de valores nulos.
# Coluna Red blood cell distribution width (RDW) não eliminada porcentagem de nulos: 89.33% de valores nulos.
# Coluna Red blood cell distribution width (RDW) será eliminada por conter 89.33% de valores nulos.
# Coluna Serum Glucose não eliminada porcentagem de nulos: 96.31% de valores nulos.
# Coluna Serum Glucose será eliminada por conter 96.31% de valores nulos.
# Coluna Respiratory Syncytial Virus não eliminada porcentagem de nulos: 76.01% de valores nulos.
# Coluna Influenza A não eliminada porcentagem de nulos: 76.01% de valores nulos.
# Coluna Influenza B não eliminada porcentagem de nulos: 76.01% de valores nulos.
# Coluna Parainfluenza 1 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna CoronavirusNL63 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Rhinovirus/Enterovirus não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Mycoplasma pneumoniae não eliminada porcentagem de nulos: 100.00% de valores nulos.
# Coluna Mycoplasma pneumoniae será eliminada por conter 100.00% de valores nulos.
# Coluna Coronavirus HKU1 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Parainfluenza 3 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Chlamydophila pneumoniae não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Adenovirus não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Parainfluenza 4 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Coronavirus229E não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna CoronavirusOC43 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Inf A H1N1 2009 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Bordetella pertussis não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Metapneumovirus não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Parainfluenza 2 não eliminada porcentagem de nulos: 76.05% de valores nulos.
# Coluna Neutrophils não eliminada porcentagem de nulos: 90.91% de valores nulos.
# Coluna Neutrophils será eliminada por conter 90.91% de valores nulos.
# Coluna Urea não eliminada porcentagem de nulos: 92.97% de valores nulos.
# Coluna Urea será eliminada por conter 92.97% de valores nulos.
# Coluna Proteina C reativa mg/dL não eliminada porcentagem de nulos: 91.03% de valores nulos.
# Coluna Proteina C reativa mg/dL será eliminada por conter 91.03% de valores nulos.
# Coluna Creatinine não eliminada porcentagem de nulos: 92.49% de valores nulos.
# Coluna Creatinine será eliminada por conter 92.49% de valores nulos.
# Coluna Potassium não eliminada porcentagem de nulos: 93.43% de valores nulos.
# Coluna Potassium será eliminada por conter 93.43% de valores nulos.
# Coluna Sodium não eliminada porcentagem de nulos: 93.44% de valores nulos.
# Coluna Sodium será eliminada por conter 93.44% de valores nulos.
# Coluna Influenza B, rapid test não eliminada porcentagem de nulos: 85.47% de valores nulos.
# Coluna Influenza A, rapid test não eliminada porcentagem de nulos: 85.47% de valores nulos.
# Coluna Alanine transaminase não eliminada porcentagem de nulos: 96.01% de valores nulos.
# Coluna Alanine transaminase será eliminada por conter 96.01% de valores nulos.
# Coluna Aspartate transaminase não eliminada porcentagem de nulos: 96.00% de valores nulos.
# Coluna Aspartate transaminase será eliminada por conter 96.00% de valores nulos.
# Coluna Gamma-glutamyltransferase  não eliminada porcentagem de nulos: 97.29% de valores nulos.
# Coluna Gamma-glutamyltransferase  será eliminada por conter 97.29% de valores nulos.
# Coluna Total Bilirubin não eliminada porcentagem de nulos: 96.78% de valores nulos.
# Coluna Total Bilirubin será eliminada por conter 96.78% de valores nulos.
# Coluna Direct Bilirubin não eliminada porcentagem de nulos: 96.78% de valores nulos.
# Coluna Direct Bilirubin será eliminada por conter 96.78% de valores nulos.
# Coluna Indirect Bilirubin não eliminada porcentagem de nulos: 96.78% de valores nulos.
# Coluna Indirect Bilirubin será eliminada por conter 96.78% de valores nulos.
# Coluna Alkaline phosphatase não eliminada porcentagem de nulos: 97.45% de valores nulos.
# Coluna Alkaline phosphatase será eliminada por conter 97.45% de valores nulos.
# Coluna Ionized calcium  não eliminada porcentagem de nulos: 99.11% de valores nulos.
# Coluna Ionized calcium  será eliminada por conter 99.11% de valores nulos.
# Coluna Strepto A não eliminada porcentagem de nulos: 94.12% de valores nulos.
# Coluna Strepto A será eliminada por conter 94.12% de valores nulos.
# Coluna Magnesium não eliminada porcentagem de nulos: 99.29% de valores nulos.
# Coluna Magnesium será eliminada por conter 99.29% de valores nulos.
# Coluna pCO2 (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna pCO2 (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna Hb saturation (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna Hb saturation (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna Base excess (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna Base excess (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna pO2 (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna pO2 (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna Fio2 (venous blood gas analysis) não eliminada porcentagem de nulos: 99.98% de valores nulos.
# Coluna Fio2 (venous blood gas analysis) será eliminada por conter 99.98% de valores nulos.
# Coluna Total CO2 (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna Total CO2 (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna pH (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna pH (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna HCO3 (venous blood gas analysis) não eliminada porcentagem de nulos: 97.59% de valores nulos.
# Coluna HCO3 (venous blood gas analysis) será eliminada por conter 97.59% de valores nulos.
# Coluna Rods # não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Rods # será eliminada por conter 98.28% de valores nulos.
# Coluna Segmented não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Segmented será eliminada por conter 98.28% de valores nulos.
# Coluna Promyelocytes não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Promyelocytes será eliminada por conter 98.28% de valores nulos.
# Coluna Metamyelocytes não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Metamyelocytes será eliminada por conter 98.28% de valores nulos.
# Coluna Myelocytes não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Myelocytes será eliminada por conter 98.28% de valores nulos.
# Coluna Myeloblasts não eliminada porcentagem de nulos: 98.28% de valores nulos.
# Coluna Myeloblasts será eliminada por conter 98.28% de valores nulos.
# Coluna Urine - Esterase não eliminada porcentagem de nulos: 98.94% de valores nulos.
# Coluna Urine - Esterase será eliminada por conter 98.94% de valores nulos.
# Coluna Urine - Aspect não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Aspect será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - pH não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - pH será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Hemoglobin não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Hemoglobin será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Bile pigments não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Bile pigments será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Ketone Bodies não eliminada porcentagem de nulos: 98.99% de valores nulos.
# Coluna Urine - Ketone Bodies será eliminada por conter 98.99% de valores nulos.
# Coluna Urine - Nitrite não eliminada porcentagem de nulos: 99.98% de valores nulos.
# Coluna Urine - Nitrite será eliminada por conter 99.98% de valores nulos.
# Coluna Urine - Density não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Density será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Urobilinogen não eliminada porcentagem de nulos: 98.78% de valores nulos.
# Coluna Urine - Urobilinogen será eliminada por conter 98.78% de valores nulos.
# Coluna Urine - Protein não eliminada porcentagem de nulos: 98.94% de valores nulos.
# Coluna Urine - Protein será eliminada por conter 98.94% de valores nulos.
# Coluna Urine - Sugar não eliminada porcentagem de nulos: 100.00% de valores nulos.
# Coluna Urine - Sugar será eliminada por conter 100.00% de valores nulos.
# Coluna Urine - Leukocytes não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Leukocytes será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Crystals não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Crystals será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Red blood cells não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Red blood cells será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Hyaline cylinders não eliminada porcentagem de nulos: 98.81% de valores nulos.
# Coluna Urine - Hyaline cylinders será eliminada por conter 98.81% de valores nulos.
# Coluna Urine - Granular cylinders não eliminada porcentagem de nulos: 98.78% de valores nulos.
# Coluna Urine - Granular cylinders será eliminada por conter 98.78% de valores nulos.
# Coluna Urine - Yeasts não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Yeasts será eliminada por conter 98.76% de valores nulos.
# Coluna Urine - Color não eliminada porcentagem de nulos: 98.76% de valores nulos.
# Coluna Urine - Color será eliminada por conter 98.76% de valores nulos.
# Coluna Partial thromboplastin time (PTT)  não eliminada porcentagem de nulos: 100.00% de valores nulos.
# Coluna Partial thromboplastin time (PTT)  será eliminada por conter 100.00% de valores nulos.
# Coluna Relationship (Patient/Normal) não eliminada porcentagem de nulos: 98.39% de valores nulos.
# Coluna Relationship (Patient/Normal) será eliminada por conter 98.39% de valores nulos.
# Coluna International normalized ratio (INR) não eliminada porcentagem de nulos: 97.64% de valores nulos.
# Coluna International normalized ratio (INR) será eliminada por conter 97.64% de valores nulos.
# Coluna Lactic Dehydrogenase não eliminada porcentagem de nulos: 98.21% de valores nulos.
# Coluna Lactic Dehydrogenase será eliminada por conter 98.21% de valores nulos.
# Coluna Prothrombin time (PT), Activity não eliminada porcentagem de nulos: 100.00% de valores nulos.
# Coluna Prothrombin time (PT), Activity será eliminada por conter 100.00% de valores nulos.
# Coluna Vitamin B12 não eliminada porcentagem de nulos: 99.95% de valores nulos.
# Coluna Vitamin B12 será eliminada por conter 99.95% de valores nulos.
# Coluna Creatine phosphokinase (CPK)  não eliminada porcentagem de nulos: 98.16% de valores nulos.
# Coluna Creatine phosphokinase (CPK)  será eliminada por conter 98.16% de valores nulos.
# Coluna Ferritin não eliminada porcentagem de nulos: 99.59% de valores nulos.
# Coluna Ferritin será eliminada por conter 99.59% de valores nulos.
# Coluna Arterial Lactic Acid não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna Arterial Lactic Acid será eliminada por conter 99.52% de valores nulos.
# Coluna Lipase dosage não eliminada porcentagem de nulos: 99.86% de valores nulos.
# Coluna Lipase dosage será eliminada por conter 99.86% de valores nulos.
# Coluna D-Dimer não eliminada porcentagem de nulos: 100.00% de valores nulos.
# Coluna D-Dimer será eliminada por conter 100.00% de valores nulos.
# Coluna Albumin não eliminada porcentagem de nulos: 99.77% de valores nulos.
# Coluna Albumin será eliminada por conter 99.77% de valores nulos.
# Coluna Hb saturation (arterial blood gases) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna Hb saturation (arterial blood gases) será eliminada por conter 99.52% de valores nulos.
# Coluna pCO2 (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna pCO2 (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna Base excess (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna Base excess (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna pH (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna pH (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna Total CO2 (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna Total CO2 (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna HCO3 (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna HCO3 (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna pO2 (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna pO2 (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.
# Coluna Arteiral Fio2 não eliminada porcentagem de nulos: 99.65% de valores nulos.
# Coluna Arteiral Fio2 será eliminada por conter 99.65% de valores nulos.
# Coluna Phosphor não eliminada porcentagem de nulos: 99.65% de valores nulos.
# Coluna Phosphor será eliminada por conter 99.65% de valores nulos.
# Coluna ctO2 (arterial blood gas analysis) não eliminada porcentagem de nulos: 99.52% de valores nulos.
# Coluna ctO2 (arterial blood gas analysis) será eliminada por conter 99.52% de valores nulos.

# %%
for col in df.select_dtypes(include="object").columns:
    if col != "Patient ID":
        df[col].replace({
            "positive": 1,
            "negative": 0,
            "detected": 1,
            "not_detected": 0,
            "present": 1,
            "absent": 0,
            "Não Realizado": float("NaN"),
            "not_done": float("NaN"),
            "<1000": 999
        }, inplace=True)

# %%
for coluna in df.columns:
    df[coluna] = df[coluna].fillna(0.0)

df.drop(["Patient ID"], axis=1, inplace=True)
df.dtypes
# Out:
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                     int64
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
# Patient addmited to intensive care unit (1=yes, 0=no)      int64
# Respiratory Syncytial Virus                              float64
# Influenza A                                              float64
# Influenza B                                              float64
# Parainfluenza 1                                          float64
# CoronavirusNL63                                          float64
# Rhinovirus/Enterovirus                                   float64
# Coronavirus HKU1                                         float64
# Parainfluenza 3                                          float64
# Chlamydophila pneumoniae                                 float64
# Adenovirus                                               float64
# Parainfluenza 4                                          float64
# Coronavirus229E                                          float64
# CoronavirusOC43                                          float64
# Inf A H1N1 2009                                          float64
# Bordetella pertussis                                     float64
# Metapneumovirus                                          float64
# Parainfluenza 2                                          float64
# Influenza B, rapid test                                  float64
# Influenza A, rapid test                                  float64
# dtype: object

# %%
def find_outliers_IQR(column_name, df):
    q1, q3 = df[column_name].quantile([0.25, 0.75])
    IQR = q3 - q1
    outliers = df[(df[column_name] < q1 - 1.5*IQR) | (df[column_name] > q3 + 1.5*IQR)]
    return outliers

def print_outliers_IQR(df):
    for column in df.columns:
        outliers = find_outliers_IQR(column, df)
        print(f"Outliers da coluna {column}: {outliers.shape[0]}")

# %%
print_outliers_IQR(df)
# Out:
# Outliers da coluna Patient age quantile: 0
# Outliers da coluna SARS-Cov-2 exam result: 558
# Outliers da coluna Patient addmited to regular ward (1=yes, 0=no): 79
# Outliers da coluna Patient addmited to semi-intensive unit (1=yes, 0=no): 50
# Outliers da coluna Patient addmited to intensive care unit (1=yes, 0=no): 41
# Outliers da coluna Respiratory Syncytial Virus: 52
# Outliers da coluna Influenza A: 18
# Outliers da coluna Influenza B: 77
# Outliers da coluna Parainfluenza 1: 3
# Outliers da coluna CoronavirusNL63: 45
# Outliers da coluna Rhinovirus/Enterovirus: 379
# Outliers da coluna Coronavirus HKU1: 20
# Outliers da coluna Parainfluenza 3: 10
# Outliers da coluna Chlamydophila pneumoniae: 9
# Outliers da coluna Adenovirus: 13
# Outliers da coluna Parainfluenza 4: 19
# Outliers da coluna Coronavirus229E: 9
# Outliers da coluna CoronavirusOC43: 8
# Outliers da coluna Inf A H1N1 2009: 98
# Outliers da coluna Bordetella pertussis: 2
# Outliers da coluna Metapneumovirus: 14
# Outliers da coluna Parainfluenza 2: 0
# Outliers da coluna Influenza B, rapid test: 49
# Outliers da coluna Influenza A, rapid test: 52
